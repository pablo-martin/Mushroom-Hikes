# %% [markdown]
# # DSA Dataset
# The Danish Svampe Atlas has 85k training images, which could definitely supplement the MO dataset, which may end up having around 300k clean images. This dataset is already clean, which is a plus, the only work would be in getting the species to match up with the MO dataset. Let's make that happen here.

# %%
import os
import json
import pickle
import numpy as np
import pandas as pd

# %%
base_dir = os.environ['HOME'] + '/python/Mushroom_Classifier/'
tables_dir = base_dir + 'DSA_info/'

#loading metadata information
with open(tables_dir + 'train.json') as json_file:
    training = json.load(json_file)
with open(tables_dir + 'val.json') as json_file:
    validation = json.load(json_file)

# %% [markdown]
# I'm going to make a pandas dataframe for this information, it'll make life much easier I think

# %%
'''given an ID, it links observation table to images table to 
species category table. sort of like a SQL join'''
def make_entry(ID, TABLE):
    out = []
    out.append(ID)
    
    #get the species name of the observation
    annotation_index = \
        [i for i, w in enumerate(TABLE['annotations']) if w['id']==ID]
    annotation_index = annotation_index[0]
    category_id = TABLE['annotations'][annotation_index]['category_id']
    name = [w['name'] for w in TABLE['categories'] \
                      if w['id'] == category_id]
    assert len(name) == 1
    out.append(str(name[0]))
    
    image_id = TABLE['annotations'][annotation_index]['image_id']
    rimage = [w for w in TABLE['images'] if w['id'] == image_id]
    out.append(rimage[0]['height'])
    out.append(rimage[0]['width'])
    out.append(str(rimage[0]['file_name']))
    return out

# %%
table = []
headers = ['id', 'name', 'height', 'width', 'file_name']

#training dataset
for i, w in enumerate([w['id'] for w in training['annotations']]):
    if i%1000 == 0:
        print('on observation %i/%i' %(i,len(training['annotations'])))
    table.append(make_entry(w, training))

#validation dataset
for i, w in enumerate([w['id'] for w in validation['annotations']]):
    if i%1000 == 0:
        print('on observation %i/%i' %(i,len(validation['annotations'])))
    table.append(make_entry(w, validation))
    
#making a dataframe from a table of tables
new_table = pd.DataFrame(table, columns=headers)

# %% [markdown]
# ## Linking to MO Taxa
# OK, we're done with this part. Next we're going to link these observations with MO taxa information to see if we'll keep them in the dataset.

# %%
def text_name_to_gs(text_name):
    fine_labels = {}
    split_name = text_name.split(' ')
    if len(split_name) == 1:
        fine_labels['Genus'] = split_name[0]
    elif len(split_name) == 2:
        fine_labels['Genus'] = split_name[0]
        fine_labels['Species'] = split_name[1]
    elif len(split_name) == 3:
        if split_name[2] == 'group':
            fine_labels['Genus'] = split_name[0]
            fine_labels['Species'] = split_name[1]     
        elif split_name[1] == 'subgenus':
            #technically not correct
            fine_labels['Genus'] = split_name[0]
            fine_labels['Species'] = split_name[2] 
    elif len(split_name) > 3:
        fine_labels['Genus'] = split_name[0]
        if split_name[1] != 'subgenus':
            fine_labels['Species'] = split_name[1]  
        else:
            fine_labels['Species'] = split_name[2]
    return fine_labels

# %%
#load MO taxa
taxa = pickle.load(open(base_dir + 'MO_tables/taxa_dict.p'))
new_table = pickle.load(open(tables_dir + 'train_val_df.p','rb'))

def name_in_taxa(name):
    name_list = text_name_to_gs(name)
    
    tmp = np.nan
    for k,w in taxa.iteritems():
        if w.get('Genus') == name_list.get('Genus') \
        and w.get('Species') == name_list.get('Species'):
            tmp = k
            break     
    return tmp

#adding taxa number
new_table['in_taxa'] = new_table.name.apply(lambda x: name_in_taxa(x))
new_table.in_taxa[new_table.in_taxa.isna()] = 0
new_table['in_taxa'] = new_table['in_taxa'].astype('int32',copy=True)

#saving dataframe to disk
pickle.dump(new_table, open(tables_dir + 'train_val_df.p', 'wb'))

# %%
new_table = pickle.load(open(tables_dir + 'train_val_df.p','rb'))
display(new_table)
# Out:
#           id                                         name  height  width  \
# 0      43829                    Leucoagaricus leucothites     732   1300
# 1      44039                    Leucoagaricus leucothites     788   1400
# 2      44255                    Leucoagaricus leucothites     788   1400
# 3      44614                    Leucoagaricus leucothites     425    567
# 4      45510                    Leucoagaricus leucothites     577    770
# 5      45649                    Leucoagaricus leucothites     577    770
# 6      53554                    Leucoagaricus leucothites     800    953
# 7      53745                    Leucoagaricus leucothites     800    776
# 8      44714                    Leucoagaricus leucothites     768    719
# 9      44851                    Leucoagaricus leucothites     768    885
# 10     45002                    Leucoagaricus leucothites     768    781
# 11     45159                    Leucoagaricus leucothites     768    946
# 12     48969                    Leucoagaricus leucothites     600    800
# 13     49931                    Leucoagaricus leucothites     768   1024
# 14     57253                    Leucoagaricus leucothites    1000   1333
# 15     45807                    Leucoagaricus leucothites     818   1090
# 16     46040                    Leucoagaricus leucothites    1035   1380
# 17     46258                    Leucoagaricus leucothites    1309    721
# 18     46418                    Leucoagaricus leucothites     900   1200
# 19     46630                    Leucoagaricus leucothites     900   1200
# 20     49163                    Leucoagaricus leucothites     900   1200
# 21     52152                    Leucoagaricus leucothites     900   1200
# 22     46804                    Leucoagaricus leucothites     794    797
# 23     47977                    Leucoagaricus leucothites     365    421
# 24     48161                    Leucoagaricus leucothites     451    506
# 25     48361                    Leucoagaricus leucothites     457    520
# 26     46986                    Leucoagaricus leucothites     601    800
# 27     47140                    Leucoagaricus leucothites     374    500
# 28     61604                    Leucoagaricus leucothites    1000   1333
# 29     47251                    Leucoagaricus leucothites     578    770
# ...      ...                                          ...     ...    ...
# 4152   41769                              Lepista sordida     937   1400
# 4153   42011                              Lepista sordida    1125   1500
# 4154   42459                              Lepista sordida     750   1000
# 4155   41837                          Leptosphaeria acuta     480    640
# 4156   41958                          Leptosphaeria acuta     480    640
# 4157   42323                          Leptosphaeria acuta     600    800
# 4158   89088                        Xerocomus ferrugineus     735   1000
# 4159   89256                        Xerocomus ferrugineus     750   1000
# 4160   89367                        Xerocomus ferrugineus     711   1000
# 4161   61398                        Psathyrella ammophila     700    933
# 4162   61606                        Psathyrella ammophila     820   1093
# 4163   61837                        Psathyrella ammophila     820   1093
# 4164   63645                      Psathyrella candolleana     868   1000
# 4165   64561                      Psathyrella candolleana     611   1087
# 4166   92487                      Psathyrella candolleana    1100    619
# 4167  104321                             Rhodocybe gemina     767   1024
# 4155  images/16261_Leptosphaeria_acuta/LSA2009PIC855...        0
# 4156  images/16261_Leptosphaeria_acuta/LSA2009PIC210...        0
# 4157  images/16261_Leptosphaeria_acuta/SVEND2012PIC5...        0
# 4158  images/40854_Xerocomus_ferrugineus/LDJ2009PIC4...    30484
# 4159  images/40854_Xerocomus_ferrugineus/LDJ2009PIC4...    30484
# 4160  images/40854_Xerocomus_ferrugineus/LDJ2009PIC3...    30484
# 4161  images/19098_Psathyrella_ammophila/ALP2010PIC1...        0
# 4162  images/19098_Psathyrella_ammophila/ALP2011PIC6...        0
# 4163  images/19098_Psathyrella_ammophila/ALP2011PIC6...        0
# 4164  images/19105_Psathyrella_candolleana/LDJ2009PI...      603
# 4165  images/19105_Psathyrella_candolleana/OBL2009PI...      603
# 4166  images/19105_Psathyrella_candolleana/OBL2013PI...      603
# 4167  images/65085_Rhodocybe_gemina/BWP2010PIC525640...    19386
# 4168  images/65085_Rhodocybe_gemina/BWP2017-9205113_...    19386
# 4169  images/65085_Rhodocybe_gemina/BWP2017-9205113_...    19386
# 4170  images/47027_Deconica_crobula/BTO2009PIC557123...        0
# 4171  images/47027_Deconica_crobula/MAV2011PIC709759...        0
# 4172  images/47027_Deconica_crobula/OBL2013PIC194891...        0
# 4173  images/63830_Cortinarius_sphagnophilus/PEL2011...        0
# 4174  images/63830_Cortinarius_sphagnophilus/PEL2011...        0
# 4175  images/63830_Cortinarius_sphagnophilus/PEL2011...        0
# 4176  images/16365_Leptosporomyces_fuscostratus/SVEN...        0
# 4177  images/16365_Leptosporomyces_fuscostratus/ML20...        0
# 4178  images/16365_Leptosporomyces_fuscostratus/ML20...        0
# 4179  images/16382_Leucoagaricus_leucothites var. ca...      444
# 4180  images/16382_Leucoagaricus_leucothites var. ca...      444
# 4181  images/16382_Leucoagaricus_leucothites var. ca...      444
#
# [89760 rows x 6 columns]

# %% [markdown]
# How many of the species in the DSA dataset do we have the full taxa information for?

# %%
Species = list(set(new_table.name))
species_in_taxa = [name_in_taxa(w) for w in Species]
species_in_taxa = [1 for w in species_in_taxa if w != None]
print('Ratio of species in MO taxa %i/%i'\
                      %(sum(species_in_taxa), len(Species)))
# Out:
# Ratio of species in MO taxa 1392/1392

# %% [markdown]
# ## Standarize Dataset to MO Format
# Mostly done with this dataset, what we need to do is to standarize to the same df that we have for the MO dataset. We are missing location, in_location, vote_cache, and when picture was taken.

# %%
#time per observation!
# %timeit create_df_from_observation(20, tmp_obs)
# Out:
# 100 loops, best of 3: 13.6 ms per loop

# %%
columns = ['id','location_id','in_location','vote_cache','when',
           'Domain', 'Kingdom', 'Phylum', 'Class', 'Order', 'Family',
           'Genus', 'Species', 'Image', 'Data_Source']

def create_df_from_observation(cid, tmp_obs):
    
    df = pd.DataFrame(np.zeros([1, len(columns)]), columns=columns)

    df.loc[:,'id'] = cid
    df.loc[:,'location_id'] = -1
    df.loc[:,'in_location'] = -1
    df.loc[:,'vote_cache'] = 3
    df.loc[:,'when'] = ''
    df.loc[:,'Image'] = tmp_obs.file_name.values[0]
    df.loc[:,'Data_Source'] = 'DSA'
    
    if tmp_obs['in_taxa'].values[0]:

        #taxa information
        for taxa_subfield in ['Domain','Kingdom','Phylum',
                              'Class','Order','Family','Genus','Species']:
            df.loc[:, taxa_subfield] = \
                            taxa[int(tmp_obs.in_taxa)].get(taxa_subfield)
    else:
        GS_dict = text_name_to_gs(tmp_obs.name.values[0])
        for taxa_subfield in ['Domain','Kingdom','Phylum',
                              'Class','Order','Family']:
            df.loc[:, taxa_subfield] = ''
        df.loc[:, 'Genus'] = GS_dict.get('Genus')
        df.loc[:, 'Species'] = GS_dict.get('Species')
        
    return df

# %%
#Estimated time for this process
secs_per_obs = 0.014
print('Total estimated minutes: %1.2f' %((secs_per_obs * new_table.shape[0]) / (60)))
# Out:
# Total estimated minutes: 20.94

# %%
J = 0
comp_df = []

for i, (cid, tmp_obs) in enumerate(new_table.iloc[J:new_table.shape[0]].groupby('id')):
    if i%1000 == 0:
        print('on observation %i/%i' %(i,new_table.shape[0]))
    tmp = create_df_from_observation(cid, tmp_obs)
    comp_df.append(tmp)
    J = i
        
df = pd.concat(comp_df)
df.loc[:,'location_id'] = df.location_id.astype('int32')
df.loc[:,'in_location'] = df.in_location.astype('int16')
# Out:
# on observation 0/89760
# on observation 1000/89760
# on observation 2000/89760
# on observation 3000/89760
# on observation 4000/89760
# on observation 5000/89760
# on observation 6000/89760
# on observation 7000/89760
# on observation 8000/89760
# on observation 9000/89760
# on observation 10000/89760
# on observation 11000/89760
# on observation 12000/89760
# on observation 13000/89760
# on observation 14000/89760
# on observation 15000/89760
# on observation 16000/89760
# on observation 17000/89760
# on observation 18000/89760
# on observation 19000/89760
# on observation 20000/89760
# on observation 21000/89760
# on observation 22000/89760
# on observation 23000/89760
# on observation 24000/89760
# on observation 25000/89760
# on observation 26000/89760
# on observation 27000/89760
# on observation 28000/89760
# on observation 29000/89760
# on observation 30000/89760
# on observation 31000/89760
# on observation 32000/89760
# on observation 33000/89760
# on observation 34000/89760
# on observation 35000/89760
# on observation 36000/89760
# on observation 37000/89760
# on observation 38000/89760
# on observation 39000/89760
# on observation 40000/89760
# on observation 41000/89760
# on observation 42000/89760
# on observation 43000/89760
# on observation 44000/89760
# on observation 45000/89760
# on observation 46000/89760
# on observation 47000/89760
# on observation 48000/89760
# on observation 49000/89760
# on observation 50000/89760
# on observation 51000/89760
# on observation 52000/89760
# on observation 53000/89760
# on observation 54000/89760
# on observation 55000/89760
# on observation 56000/89760
# on observation 57000/89760
# on observation 58000/89760
# on observation 59000/89760
# on observation 60000/89760
# on observation 61000/89760
# on observation 62000/89760
# on observation 63000/89760
# on observation 64000/89760
# on observation 65000/89760
# on observation 66000/89760
# on observation 67000/89760
# on observation 68000/89760
# on observation 69000/89760
# on observation 70000/89760
# 0      Agaricus       bernardii
# 0      Agaricus          langei
# 0      Agaricus        moelleri
# ..          ...             ...
# 0      Sutorius    luridiformis
# 0       Xylodon       paradoxus
# 0   Coprinellus        micaceus
# 0      Sutorius    luridiformis
# 0       Xylodon       paradoxus
# 0   Coprinellus        micaceus
# 0      Sutorius    luridiformis
# 0       Xylodon       paradoxus
# 0      Sutorius    luridiformis
# 0   Coprinellus        micaceus
# 0       Xylodon       paradoxus
# 0      Sutorius    luridiformis
# 0   Coprinellus        micaceus
# 0       Xylodon       paradoxus
# 0      Sutorius    luridiformis
# 0       Xylodon       paradoxus
# 0      Sutorius    luridiformis
# 0       Xylodon       paradoxus
# 0       Xylodon       paradoxus
# 0       Xylodon       paradoxus
# 0      Sutorius    luridiformis
# 0       Xylodon       paradoxus
# 0      Sutorius    luridiformis
# 0       Xylodon       paradoxus
# 0       Xylodon       paradoxus
# 0       Xylodon       paradoxus
# 0      Sutorius    luridiformis
# 0       Xylodon       paradoxus
# 0       Xylodon       paradoxus
# 0      Sutorius    luridiformis
#
#                                                 Image Data_Source
# 0   images/10000_Abortiporus_biennis/FVL2009PIC655...         DSA
# 0   images/10025_Achroomyces_disciformis/LDJ2009PI...         DSA
# 0   images/10000_Abortiporus_biennis/FVL2009PIC490...         DSA
# 0   images/10052_Agaricus_altipes/PEL2010PIC323258...         DSA
# 0   images/10025_Achroomyces_disciformis/LDJ2009PI...         DSA
# 0   images/10052_Agaricus_altipes/PEL2010PIC574673...         DSA
# 0   images/10057_Agaricus_augustus/MHA2009PIC46158...         DSA
# 0   images/10025_Achroomyces_disciformis/LDJ2009PI...         DSA
# 0   images/10061_Agaricus_bisporus/LDJ2009PIC84491...         DSA
# 0   images/10062_Agaricus_bitorquis/JAH2009PIC6497...         DSA
# 0   images/10065_Agaricus_campestris/LSA2009PIC772...         DSA
# 0   images/10068_Agaricus_comtulus/RE2009PIC698265...         DSA
# 0   images/10057_Agaricus_augustus/MHA2009PIC67879...         DSA
# 0   images/10025_Achroomyces_disciformis/LDJ2009PI...         DSA
# 0   images/10069_Agaricus_cupreobrunneus/AS2009PIC...         DSA
# 0   images/10061_Agaricus_bisporus/LDJ2009PIC85447...         DSA
# 0   images/10056_Agaricus_arvensis/LSA2009PIC17523...         DSA
# 0   images/10068_Agaricus_comtulus/ML2009PIC707838...         DSA
# 0   images/10069_Agaricus_cupreobrunneus/TKH2010PI...         DSA
# 0   images/10079_Agaricus_impudicus/RE2009PIC46418...         DSA
# 0   images/10025_Achroomyces_disciformis/LDJ2009PI...         DSA
# 0   images/10056_Agaricus_arvensis/NES2009PIC31125...         DSA
# 0   images/10000_Abortiporus_biennis/BTO2010PIC705...         DSA
# 0   images/10068_Agaricus_comtulus/ML2009PIC147467...         DSA
# 0   images/10083_Agaricus_lanipes/JM2010PIC2977172...         DSA
# 0   images/10079_Agaricus_impudicus/AS2009PIC44907...         DSA
# 0   images/10085_Agaricus_litoralis/JHP2009PIC7456...         DSA
# 0   images/10059_Agaricus_bernardii/FVL2009PIC8902...         DSA
# 0   images/10082_Agaricus_langei/MMN2009PIC3781749...         DSA
# 0   images/10090_Agaricus_moelleri/RE2009PIC196563...         DSA
# ..                                                ...         ...
# 0   images/67628_Sutorius_luridiformis/CUV2017-922...         DSA
# 0   images/67679_Xylodon_paradoxus/OMA2017-9187838...         DSA
# 0   images/61207_Coprinellus_micaceus/BNB2017-9223...         DSA
# 0   images/67628_Sutorius_luridiformis/UFN2017-922...         DSA
# 0   images/67679_Xylodon_paradoxus/OMA2017-9187838...         DSA
# 0   images/61207_Coprinellus_micaceus/SOT2017-9228...         DSA
# 0   images/67628_Sutorius_luridiformis/FS2017-9227...         DSA
# 0   images/67679_Xylodon_paradoxus/OMA2017-9187441...         DSA
# 0   images/67628_Sutorius_luridiformis/FS2017-9227...         DSA
# 0   images/61207_Coprinellus_micaceus/SOT2017-9228...         DSA
# 0   images/67679_Xylodon_paradoxus/OMA2017-9187441...         DSA
# 0   images/67628_Sutorius_luridiformis/FS2017-9227...         DSA
# 0   images/61207_Coprinellus_micaceus/SOT2017-9228...         DSA
# 0   images/67679_Xylodon_paradoxus/OMA2017-9187441...         DSA
# 0   images/67628_Sutorius_luridiformis/SDBD2017-92...         DSA
# 0   images/67679_Xylodon_paradoxus/MC2017-9189893_...         DSA
# 0   images/67628_Sutorius_luridiformis/SDBD2017-92...         DSA
# 0   images/67679_Xylodon_paradoxus/TIL2017-9190380...         DSA
# 0   images/67679_Xylodon_paradoxus/TIL2017-9190380...         DSA
# 0   images/67679_Xylodon_paradoxus/TIL2017-9190380...         DSA
# 0   images/67628_Sutorius_luridiformis/SDBD2017-92...         DSA
# 0   images/67679_Xylodon_paradoxus/TIL2017-9190380...         DSA
# 0   images/67628_Sutorius_luridiformis/MC2017-9228...         DSA
# 0   images/67679_Xylodon_paradoxus/MC2017-9191183_...         DSA
# 0   images/67679_Xylodon_paradoxus/MC2017-9191193_...         DSA
# 0   images/67679_Xylodon_paradoxus/UFN2017-9192270...         DSA
# 0   images/67628_Sutorius_luridiformis/MC2017-9228...         DSA
# 0   images/67679_Xylodon_paradoxus/UFN2017-9196099...         DSA
# 0   images/67679_Xylodon_paradoxus/UFN2017-9196099...         DSA
# 0   images/67628_Sutorius_luridiformis/MC2017-9228...         DSA
#
# [89760 rows x 15 columns]

# %%
for taxa_field in ['Domain','Phylum','Class','Order','Family','Genus','Species']:
    print('working on: %s' %taxa_field)
    df.loc[df[taxa_field].apply(lambda x: x==None), taxa_field] = ''
    df.loc[df[taxa_field].apply(lambda x: not isinstance(x,str)), taxa_field] = ''
# Out:
# working on: Domain
# working on: Phylum
# working on: Class
# working on: Order
# working on: Family
# working on: Genus
# working on: Species

# %%
pickle.dump(df, open(tables_dir + 'finished_df_DSA.p', 'wb'))

# %% [markdown]
# And we're done.
